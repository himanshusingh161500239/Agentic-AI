# %%
# !pip install pydantic_ai
# Out:
# Collecting pydantic_ai
#   Downloading pydantic_ai-0.6.2-py3-none-any.whl.metadata (11 kB)
# Collecting pydantic-ai-slim==0.6.2 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading pydantic_ai_slim-0.6.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting eval-type-backport>=0.2.0 (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: griffe>=1.3.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.8.0)
# Requirement already satisfied: httpx>=0.27 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.28.1)
# Requirement already satisfied: opentelemetry-api>=1.28.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.35.0)
# Collecting pydantic-graph==0.6.2 (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading pydantic_graph-0.6.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pydantic>=2.10 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.11.7)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.4.1)
# Collecting ag-ui-protocol>=0.1.8 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading ag_ui_protocol-0.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: starlette>=0.45.3 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.47.2)
# Collecting anthropic>=0.61.0 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading anthropic-0.62.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: boto3>=1.39.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.39.14)
# Collecting argcomplete>=3.5.0 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: prompt-toolkit>=3 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.0.51)
# Requirement already satisfied: rich>=13 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (14.1.0)
# Collecting cohere>=5.16.0 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading cohere-5.16.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic-evals==0.6.2 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading pydantic_evals-0.6.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting google-genai>=1.28.0 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading google_genai-1.29.0-py3-none-any.whl.metadata (43 kB)
# Collecting groq>=0.25.0 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading groq-0.31.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: huggingface-hub>=0.33.5 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.34.1)
# Requirement already satisfied: mcp>=1.10.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.12.2)
# Collecting mistralai>=1.9.2 (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading mistralai-1.9.3-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: openai>=1.92.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.97.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (9.1.2)
# Requirement already satisfied: google-auth>=2.36.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.40.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.32.4)
# Requirement already satisfied: anyio>=0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-evals==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (4.9.0)
# Collecting logfire-api>=1.2.0 (from pydantic-evals==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading logfire_api-4.2.0-py3-none-any.whl.metadata (971 bytes)
# Requirement already satisfied: pyyaml>=6.0.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-evals==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (6.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from anthropic>=0.61.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from anthropic>=0.61.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.10.0)
# Requirement already satisfied: sniffio in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from anthropic>=0.61.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from anyio>=0->pydantic-evals==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.10)
# Requirement already satisfied: certifi in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from httpx>=0.27->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.16.0)
# Requirement already satisfied: botocore<1.40.0,>=1.39.14 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.39.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.13.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from botocore<1.40.0,>=1.39.14->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from botocore<1.40.0,>=1.39.14->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.5.0)
# Requirement already satisfied: six>=1.5 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.14->boto3>=1.39.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.17.0)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere>=5.16.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading fastavro-1.12.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (5.7 kB)
# Collecting httpx-sse==0.4.0 (from cohere>=5.16.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting tokenizers<1,>=0.15 (from cohere>=5.16.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai)
#   Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from cohere>=5.16.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.32.4.20250611)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from requests>=2.32.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.4.2)
# Requirement already satisfied: filelock in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (25.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub>=0.33.5->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.1.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=2.36.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.6.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from google-genai>=1.28.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (14.2)
# Requirement already satisfied: colorama>=0.4 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from griffe>=1.3.2->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.4.6)
# Requirement already satisfied: aiohttp in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.12.14)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (4.25.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.0.0)
# Requirement already satisfied: uvicorn>=0.23.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.35.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.26.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.6.2->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.23.0)
# Requirement already satisfied: wcwidth in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.2.13)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.1.2)
# Requirement already satisfied: click>=7.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from uvicorn>=0.23.1->mcp>=1.10.0->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (8.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from aiohttp->huggingface-hub[inference]>=0.33.5; extra == "huggingface"->pydantic-ai-slim[ag-ui,anthropic,bedrock,cli,cohere,evals,google,groq,huggingface,mcp,mistral,openai,retries,vertexai]==0.6.2->pydantic_ai) (1.20.1)
# Downloading pydantic_ai-0.6.2-py3-none-any.whl (10 kB)
# Downloading pydantic_ai_slim-0.6.2-py3-none-any.whl (259 kB)
# Downloading pydantic_evals-0.6.2-py3-none-any.whl (52 kB)
# Downloading pydantic_graph-0.6.2-py3-none-any.whl (27 kB)
# Downloading ag_ui_protocol-0.1.8-py3-none-any.whl (7.1 kB)
# Downloading anthropic-0.62.0-py3-none-any.whl (296 kB)
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
# Downloading cohere-5.16.3-py3-none-any.whl (295 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading fastavro-1.12.0-cp313-cp313-macosx_10_13_universal2.whl (936 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.2/936.2 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading google_genai-1.29.0-py3-none-any.whl (222 kB)
# Downloading groq-0.31.0-py3-none-any.whl (131 kB)
# Downloading logfire_api-4.2.0-py3-none-any.whl (87 kB)
# Downloading mistralai-1.9.3-py3-none-any.whl (426 kB)
# Installing collected packages: logfire-api, httpx-sse, fastavro, eval-type-backport, argcomplete, tokenizers, pydantic-graph, mistralai, groq, google-genai, anthropic, ag-ui-protocol, pydantic-ai-slim, cohere, pydantic-evals, pydantic_ai
#   Attempting uninstall: httpx-sse
#     Found existing installation: httpx-sse 0.4.1
#     Uninstalling httpx-sse-0.4.1:
#       Successfully uninstalled httpx-sse-0.4.1
#   Attempting uninstall: anthropicm╸━━━━━━━━━━━━━━━━━  9/16 [google-genai]
#     Found existing installation: anthropic 0.59.0━━━━━━━━━━━━━  9/16 [google-genai]
#     Uninstalling anthropic-0.59.0:╺━━━━━━━━━━━━━━ 10/16 [anthropic]
#       Successfully uninstalled anthropic-0.59.0m━━━━━━━━━━━━━━ 10/16 [anthropic]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [pydantic_ai] [cohere]c-ai-slim]
# Successfully installed ag-ui-protocol-0.1.8 anthropic-0.62.0 argcomplete-3.6.2 cohere-5.16.3 eval-type-backport-0.2.2 fastavro-1.12.0 google-genai-1.29.0 groq-0.31.0 httpx-sse-0.4.0 logfire-api-4.2.0 mistralai-1.9.3 pydantic-ai-slim-0.6.2 pydantic-evals-0.6.2 pydantic-graph-0.6.2 pydantic_ai-0.6.2 tokenizers-0.21.4
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install logfire
# Out:
# Collecting logfire
#   Downloading logfire-4.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: executing>=2.0.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from logfire) (2.2.0)
# Collecting opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0 (from logfire)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation>=0.41b0 (from logfire)
#   Downloading opentelemetry_instrumentation-0.57b0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: opentelemetry-sdk<1.37.0,>=1.21.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from logfire) (1.35.0)
# Requirement already satisfied: protobuf>=4.23.4 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from logfire) (5.29.5)
# Requirement already satisfied: rich>=13.4.2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from logfire) (14.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from logfire) (4.14.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (1.70.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (1.35.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire)
#   Downloading opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<1.37.0,>=1.21.0 (from logfire)
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests~=2.7 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (2.32.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (3.23.0)
# Collecting opentelemetry-api~=1.15 (from opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire)
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk<1.37.0,>=1.21.0->logfire)
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http<1.37.0,>=1.21.0->logfire) (2025.7.14)
# Requirement already satisfied: packaging>=18.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from opentelemetry-instrumentation>=0.41b0->logfire) (25.0)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation>=0.41b0->logfire)
#   Downloading wrapt-1.17.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from rich>=13.4.2->logfire) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from rich>=13.4.2->logfire) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/himanshu.r.singh/Desktop/AgenticAI/agenticAI/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.4.2->logfire) (0.1.2)
# Downloading logfire-4.2.0-py3-none-any.whl (212 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading opentelemetry_instrumentation-0.57b0-py3-none-any.whl (32 kB)
# Downloading wrapt-1.17.2-cp313-cp313-macosx_11_0_arm64.whl (38 kB)
# Installing collected packages: wrapt, opentelemetry-proto, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-exporter-otlp-proto-http, logfire
#   Attempting uninstall: opentelemetry-api━━━━━━━━━━━━━━━ 2/9 [opentelemetry-exporter-otlp-proto-common]
#     Found existing installation: opentelemetry-api 1.35.02/9 [opentelemetry-exporter-otlp-proto-common]
#     Uninstalling opentelemetry-api-1.35.0:━━━━━━━━━━ 2/9 [opentelemetry-exporter-otlp-proto-common]
#       Successfully uninstalled opentelemetry-api-1.35.0━━━━━━━━━━━ 3/9 [opentelemetry-api]o-common]
#   Attempting uninstall: opentelemetry-semantic-conventions━━━━━━━━ 3/9 [opentelemetry-api]
#     Found existing installation: opentelemetry-semantic-conventions 0.56b09 [opentelemetry-api]
#     Uninstalling opentelemetry-semantic-conventions-0.56b0:━━━ 3/9 [opentelemetry-api]
#       Successfully uninstalled opentelemetry-semantic-conventions-0.56b03/9 [opentelemetry-api]
#   Attempting uninstall: opentelemetry-sdk0m━━━━━━━━━━━━━━━━━━━ 4/9 [opentelemetry-semantic-conventions]
#     Found existing installation: opentelemetry-sdk 1.35.0━ 4/9 [opentelemetry-semantic-conventions]
#     Uninstalling opentelemetry-sdk-1.35.0:━━━━━━━━━━━━━━━━ 4/9 [opentelemetry-semantic-conventions]
#       Successfully uninstalled opentelemetry-sdk-1.35.0━━━ 4/9 [opentelemetry-semantic-conventions]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [logfire]m8/9 [logfire]metry-instrumentation]
# Successfully installed logfire-4.2.0 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-http-1.36.0 opentelemetry-instrumentation-0.57b0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 wrapt-1.17.2
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from pydantic_ai import Agent
from pydantic_ai.models.bedrock import BedrockConverseModel
from pydantic_ai.providers.bedrock import BedrockProvider

import logfire

logfire.configure(token='pylf_v1_us_bcBZ6XRCQw3kx7ChmFKGhGWVh58PbQdvQ1vrPlmJs9dl')
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL:
# ]8;id=924825;https://logfire-us.pydantic.dev/himanshusingh/starter-project\https://logfire-us.pydantic.dev/himanshusingh/starter-project]8;;\

# %%
import boto3
bedrock_client = boto3.client('bedrock-runtime', region_name='us-east-1')
model = BedrockConverseModel(
    'anthropic.claude-3-sonnet-20240229-v1:0',
    provider=BedrockProvider(
        region_name='us-east-1',
        aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
        aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY'),
    ),
)
agent = Agent(model)

# %%
result = await agent.run('What is langgraph used for?')
# Out:
# 13:26:44.485 agent run
# 13:26:44.488   chat anthropic.claude-3-sonnet-20240229-v1:0

# %%
print(result.output)
# Out:
# Langgraph is an open-source tool used for visualizing language models and their internal representations. It is primarily used for analyzing and understanding the behavior of large language models, such as GPT models, by providing a visual interface to explore the model's activations and attention patterns.
#
# Some of the key features and use cases of Langgraph include:
#
# 1. Attention visualization: Langgraph allows users to visualize the attention patterns of transformer-based language models, providing insights into how the model attends to different parts of the input when generating text.
#
# 2. Activation visualization: It can visualize the activations of different layers and neurons within the language model, helping researchers and developers understand how the model processes and represents information.
#
# 3. Probing and analysis: Langgraph provides tools for probing the model's representations, allowing users to analyze how the model encodes various linguistic properties, such as syntax, semantics, and discourse structure.
#
# 4. Debugging and model understanding: By visualizing the inner workings of language models, Langgraph can help researchers and developers identify potential issues, biases, or unexpected behaviors, leading to better understanding and improvement of these models.
#
# 5. Education and research: Langgraph can be used as an educational tool for teaching and understanding the principles of transformer-based language models and as a research tool for exploring new architectures, representations, and techniques.
#
# Overall, Langgraph is a valuable tool for researchers, developers, and educators working with large language models, as it provides a way to visually inspect and analyze the complex internal representations and behaviors of these models.
